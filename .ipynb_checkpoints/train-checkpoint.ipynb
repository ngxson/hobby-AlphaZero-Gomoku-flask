# %%
# -*- coding: utf-8 -*-
"""
An implementation of the training pipeline of AlphaZero for Gomoku

@author: Junxiao Song
"""

from __future__ import print_function
import random
import numpy as np
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure
from mcts_alphaZero import MCTSPlayer
from policy_value_net_keras import PolicyValueNet # Keras
# Out:
# Using TensorFlow backend.

# %%
class TrainPipeline():
    def __init__(self, init_model=None):
        # params of the board and the game
        self.board_width = 12
        self.board_height = 12
        self.n_in_row = 5
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # training params
        self.learn_rate = 2e-3
        self.lr_multiplier = 1.0  # adaptively adjust the learning rate based on KL
        self.temp = 1.0  # the temperature param
        self.n_playout = 400  # num of simulations for each move
        self.c_puct = 5
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size)
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02
        self.check_freq = 50
        self.game_batch_num = 1500
        self.best_win_ratio = 0.0
        # num of simulations used for the pure mcts, which is used as
        # the opponent to evaluate the trained policy
        self.pure_mcts_playout_num = 1000
        if init_model:
            # start training from an initial policy-value net
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height,
                                                   model_file=init_model)
        else:
            # start training from a new policy-value net
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height)
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)

    def get_equi_data(self, play_data):
        """augment the data set by rotation and flipping
        play_data: [(state, mcts_prob, winner_z), ..., ...]
        """
        extend_data = []
        for state, mcts_porb, winner in play_data:
            for i in [1, 2, 3, 4]:
                # rotate counterclockwise
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(
                    mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state,
                                    np.flipud(equi_mcts_prob).flatten(),
                                    winner))
                # flip horizontally
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state,
                                    np.flipud(equi_mcts_prob).flatten(),
                                    winner))
        return extend_data

    def collect_selfplay_data(self, n_games=1):
        """collect self-play data for training"""
        for i in range(n_games):
            winner, play_data = self.game.start_self_play(self.mcts_player,
                                                          temp=self.temp)
            play_data = list(play_data)[:]
            self.episode_len = len(play_data)
            # augment the data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)

    def policy_update(self):
        """update the policy-value net"""
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # adaptively adjust the learning rate
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    def policy_evaluate(self, n_games=10):
        """
        Evaluate the trained policy by playing against the pure MCTS player
        Note: this is only for monitoring the progress of training
        """
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct,
                                         n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5,
                                     n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            winner = self.game.start_play(current_mcts_player,
                                          pure_mcts_player,
                                          start_player=i % 2,
                                          is_shown=0)
            win_cnt[winner] += 1
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        """run the training pipeline"""
        try:
            for i in range(self.game_batch_num):
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(
                        i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # check the performance of the current model,
                # and save the model params
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("New best policy!!!!!!!!")
                        self.best_win_ratio = win_ratio
                        # update the best_policy
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')

# %%
training_pipeline = TrainPipeline()
training_pipeline.run()
# Out:
# batch i:1, episode_len:38
# batch i:2, episode_len:73
# kl:0.00503,lr_multiplier:1.500,loss:5.943051815032959,entropy:4.966987609863281,explained_var_old:-0.054,explained_var_new:0.188
# batch i:3, episode_len:37
# kl:0.05150,lr_multiplier:1.000,loss:5.553645133972168,entropy:4.860776901245117,explained_var_old:0.200,explained_var_new:0.464
# batch i:4, episode_len:56
# kl:0.02971,lr_multiplier:1.000,loss:5.410057067871094,entropy:4.787075519561768,explained_var_old:0.215,explained_var_new:0.513
# batch i:5, episode_len:32
# kl:0.02008,lr_multiplier:1.000,loss:5.13229513168335,entropy:4.752115249633789,explained_var_old:0.446,explained_var_new:0.663
# batch i:6, episode_len:38
# kl:0.07499,lr_multiplier:0.667,loss:4.870880603790283,entropy:4.762134552001953,explained_var_old:0.659,explained_var_new:0.856
# batch i:7, episode_len:56
# kl:0.03427,lr_multiplier:0.667,loss:4.696565628051758,entropy:4.4845380783081055,explained_var_old:0.870,explained_var_new:0.916
# batch i:8, episode_len:31
# kl:0.01761,lr_multiplier:0.667,loss:4.900397300720215,entropy:4.5413641929626465,explained_var_old:0.605,explained_var_new:0.682
# batch i:9, episode_len:54
# kl:0.01935,lr_multiplier:0.667,loss:4.81522798538208,entropy:4.514928340911865,explained_var_old:0.683,explained_var_new:0.726
# batch i:10, episode_len:42
# kl:0.03887,lr_multiplier:0.667,loss:4.636318206787109,entropy:4.441036224365234,explained_var_old:0.736,explained_var_new:0.789
# batch i:11, episode_len:47
# kl:0.02615,lr_multiplier:0.667,loss:4.982219696044922,entropy:4.4015398025512695,explained_var_old:0.411,explained_var_new:0.436
# batch i:12, episode_len:27
# kl:0.03036,lr_multiplier:0.667,loss:4.931677341461182,entropy:4.319228172302246,explained_var_old:0.365,explained_var_new:0.446
# batch i:13, episode_len:48
# kl:0.03678,lr_multiplier:0.667,loss:4.870213985443115,entropy:4.267134189605713,explained_var_old:0.350,explained_var_new:0.433
# batch i:14, episode_len:36
# kl:0.04278,lr_multiplier:0.444,loss:4.639710903167725,entropy:4.28022575378418,explained_var_old:0.581,explained_var_new:0.616
# batch i:15, episode_len:42
# kl:0.02720,lr_multiplier:0.444,loss:4.776937484741211,entropy:4.308468341827393,explained_var_old:0.430,explained_var_new:0.523
# batch i:16, episode_len:31
# kl:0.01989,lr_multiplier:0.444,loss:4.880179405212402,entropy:4.265890598297119,explained_var_old:0.329,explained_var_new:0.377
# batch i:17, episode_len:42
# kl:0.04076,lr_multiplier:0.296,loss:4.830738544464111,entropy:4.107881546020508,explained_var_old:0.298,explained_var_new:0.344
# batch i:18, episode_len:38
# kl:0.02907,lr_multiplier:0.296,loss:4.758284091949463,entropy:4.30629825592041,explained_var_old:0.430,explained_var_new:0.456
# batch i:19, episode_len:70
# kl:0.02455,lr_multiplier:0.296,loss:4.693802356719971,entropy:4.093473434448242,explained_var_old:0.432,explained_var_new:0.472
# batch i:20, episode_len:42
# kl:0.02556,lr_multiplier:0.296,loss:4.57290506362915,entropy:4.178228378295898,explained_var_old:0.505,explained_var_new:0.542
# batch i:21, episode_len:48
# kl:0.01420,lr_multiplier:0.296,loss:4.629828929901123,entropy:4.1220245361328125,explained_var_old:0.524,explained_var_new:0.559
# batch i:22, episode_len:62
# kl:0.01948,lr_multiplier:0.296,loss:4.503098964691162,entropy:4.147073745727539,explained_var_old:0.561,explained_var_new:0.595
# batch i:23, episode_len:27
# kl:0.01212,lr_multiplier:0.296,loss:4.671996593475342,entropy:4.10286808013916,explained_var_old:0.430,explained_var_new:0.477
# batch i:24, episode_len:48
# kl:0.02308,lr_multiplier:0.296,loss:4.491071701049805,entropy:4.071555137634277,explained_var_old:0.501,explained_var_new:0.560
# batch i:25, episode_len:46
# kl:0.02470,lr_multiplier:0.296,loss:4.4390106201171875,entropy:4.019183158874512,explained_var_old:0.565,explained_var_new:0.601
# batch i:26, episode_len:58
# kl:0.02773,lr_multiplier:0.296,loss:4.357715606689453,entropy:4.057453155517578,explained_var_old:0.636,explained_var_new:0.671
# batch i:27, episode_len:60
# kl:0.02109,lr_multiplier:0.296,loss:4.452153205871582,entropy:4.067653179168701,explained_var_old:0.580,explained_var_new:0.621
# batch i:28, episode_len:56
# kl:0.02318,lr_multiplier:0.296,loss:4.405234336853027,entropy:4.010512828826904,explained_var_old:0.597,explained_var_new:0.615
# batch i:29, episode_len:50
# kl:0.02901,lr_multiplier:0.296,loss:4.346502780914307,entropy:3.8620362281799316,explained_var_old:0.521,explained_var_new:0.553
# batch i:30, episode_len:36
# kl:0.02756,lr_multiplier:0.296,loss:4.183620929718018,entropy:3.8860599994659424,explained_var_old:0.606,explained_var_new:0.654
# batch i:31, episode_len:41
# kl:0.02125,lr_multiplier:0.296,loss:4.395942211151123,entropy:3.8675577640533447,explained_var_old:0.503,explained_var_new:0.528
# batch i:32, episode_len:36
# kl:0.03573,lr_multiplier:0.296,loss:4.3357834815979,entropy:3.818953037261963,explained_var_old:0.421,explained_var_new:0.500
# batch i:33, episode_len:67
# kl:0.02861,lr_multiplier:0.296,loss:4.4331560134887695,entropy:3.8531229496002197,explained_var_old:0.371,explained_var_new:0.412
# batch i:34, episode_len:41
# kl:0.02952,lr_multiplier:0.296,loss:4.56644868850708,entropy:3.876230001449585,explained_var_old:0.289,explained_var_new:0.337
# batch i:35, episode_len:34
# kl:0.03101,lr_multiplier:0.296,loss:4.418614864349365,entropy:3.786940574645996,explained_var_old:0.299,explained_var_new:0.368
# batch i:36, episode_len:33
# kl:0.02398,lr_multiplier:0.296,loss:4.4012675285339355,entropy:3.809223175048828,explained_var_old:0.388,explained_var_new:0.440
# batch i:37, episode_len:32
# kl:0.03442,lr_multiplier:0.296,loss:4.478958606719971,entropy:3.873500347137451,explained_var_old:0.333,explained_var_new:0.394
# batch i:38, episode_len:42
# kl:0.03605,lr_multiplier:0.296,loss:4.364579677581787,entropy:3.804446220397949,explained_var_old:0.393,explained_var_new:0.461
# batch i:39, episode_len:48
# kl:0.02040,lr_multiplier:0.296,loss:4.442477226257324,entropy:3.8269951343536377,explained_var_old:0.338,explained_var_new:0.408
# batch i:40, episode_len:41
# kl:0.03279,lr_multiplier:0.296,loss:4.307106018066406,entropy:3.740752696990967,explained_var_old:0.435,explained_var_new:0.462
# batch i:41, episode_len:29
# kl:0.03723,lr_multiplier:0.296,loss:4.3141655921936035,entropy:3.7423760890960693,explained_var_old:0.400,explained_var_new:0.455
# batch i:42, episode_len:29
# kl:0.02747,lr_multiplier:0.296,loss:4.495567798614502,entropy:3.8341612815856934,explained_var_old:0.310,explained_var_new:0.377
# batch i:43, episode_len:36
# kl:0.03085,lr_multiplier:0.296,loss:4.401093006134033,entropy:3.7804439067840576,explained_var_old:0.328,explained_var_new:0.372
# batch i:44, episode_len:52
# kl:0.02253,lr_multiplier:0.296,loss:4.377670764923096,entropy:3.7780423164367676,explained_var_old:0.373,explained_var_new:0.416
# batch i:45, episode_len:26
# kl:0.03058,lr_multiplier:0.296,loss:4.349624156951904,entropy:3.748004913330078,explained_var_old:0.408,explained_var_new:0.447
# batch i:46, episode_len:36
# kl:0.03821,lr_multiplier:0.296,loss:4.258902549743652,entropy:3.685277223587036,explained_var_old:0.405,explained_var_new:0.444
# batch i:47, episode_len:51
# kl:0.04332,lr_multiplier:0.198,loss:4.343917369842529,entropy:3.731266736984253,explained_var_old:0.342,explained_var_new:0.412
# batch i:48, episode_len:50
# kl:0.02203,lr_multiplier:0.198,loss:4.378035068511963,entropy:3.7011990547180176,explained_var_old:0.328,explained_var_new:0.348
# batch i:49, episode_len:33
# kl:0.01560,lr_multiplier:0.198,loss:4.391838073730469,entropy:3.732563018798828,explained_var_old:0.278,explained_var_new:0.330
# batch i:50, episode_len:30
# kl:0.02762,lr_multiplier:0.198,loss:4.336207389831543,entropy:3.670419931411743,explained_var_old:0.285,explained_var_new:0.348
# current self-play batch: 50
# num_playouts:1000, win: 0, lose: 10, tie:0
# batch i:51, episode_len:38
# kl:0.01653,lr_multiplier:0.198,loss:4.3731689453125,entropy:3.7066054344177246,explained_var_old:0.340,explained_var_new:0.374
# batch i:52, episode_len:40
# kl:0.02419,lr_multiplier:0.198,loss:4.293972492218018,entropy:3.6054975986480713,explained_var_old:0.318,explained_var_new:0.358
# batch i:53, episode_len:52
# kl:0.01600,lr_multiplier:0.198,loss:4.2871599197387695,entropy:3.639697790145874,explained_var_old:0.327,explained_var_new:0.376
# batch i:54, episode_len:15
# kl:0.01956,lr_multiplier:0.198,loss:4.298971652984619,entropy:3.693833827972412,explained_var_old:0.374,explained_var_new:0.415
# batch i:55, episode_len:38
# kl:0.02298,lr_multiplier:0.198,loss:4.271576881408691,entropy:3.6626110076904297,explained_var_old:0.361,explained_var_new:0.404
# batch i:56, episode_len:46
# kl:0.02387,lr_multiplier:0.198,loss:4.194460868835449,entropy:3.609116315841675,explained_var_old:0.390,explained_var_new:0.422
# batch i:57, episode_len:49
# kl:0.03046,lr_multiplier:0.198,loss:4.384311199188232,entropy:3.6817238330841064,explained_var_old:0.272,explained_var_new:0.314
# batch i:58, episode_len:40
# kl:0.02416,lr_multiplier:0.198,loss:4.406652450561523,entropy:3.658456325531006,explained_var_old:0.264,explained_var_new:0.291
# batch i:59, episode_len:40
# kl:0.03256,lr_multiplier:0.198,loss:4.370965003967285,entropy:3.6282715797424316,explained_var_old:0.223,explained_var_new:0.267
# batch i:60, episode_len:36
# kl:0.02907,lr_multiplier:0.198,loss:4.331374168395996,entropy:3.5723471641540527,explained_var_old:0.257,explained_var_new:0.304
# batch i:61, episode_len:43
# kl:0.01446,lr_multiplier:0.198,loss:4.26952600479126,entropy:3.5279693603515625,explained_var_old:0.255,explained_var_new:0.292
# batch i:62, episode_len:34
# kl:0.02434,lr_multiplier:0.198,loss:4.301596641540527,entropy:3.631455898284912,explained_var_old:0.268,explained_var_new:0.314
# batch i:63, episode_len:28
# kl:0.02385,lr_multiplier:0.198,loss:4.315907955169678,entropy:3.5706419944763184,explained_var_old:0.287,explained_var_new:0.321
# batch i:64, episode_len:36
# kl:0.02524,lr_multiplier:0.198,loss:4.26758337020874,entropy:3.518833875656128,explained_var_old:0.249,explained_var_new:0.303
# batch i:65, episode_len:42
# kl:0.01556,lr_multiplier:0.198,loss:4.270418643951416,entropy:3.667795181274414,explained_var_old:0.330,explained_var_new:0.368
# batch i:66, episode_len:26
# kl:0.02437,lr_multiplier:0.198,loss:4.274484634399414,entropy:3.474909782409668,explained_var_old:0.214,explained_var_new:0.274
# batch i:67, episode_len:33
# kl:0.02278,lr_multiplier:0.198,loss:4.182380676269531,entropy:3.527553081512451,explained_var_old:0.345,explained_var_new:0.373
# batch i:68, episode_len:36
# kl:0.02729,lr_multiplier:0.198,loss:4.2712225914001465,entropy:3.536283493041992,explained_var_old:0.231,explained_var_new:0.264
# batch i:69, episode_len:28
# kl:0.01976,lr_multiplier:0.198,loss:4.297922134399414,entropy:3.567135810852051,explained_var_old:0.246,explained_var_new:0.292
# batch i:70, episode_len:47
# kl:0.03216,lr_multiplier:0.198,loss:4.325210094451904,entropy:3.521836996078491,explained_var_old:0.177,explained_var_new:0.214
# batch i:71, episode_len:37
# kl:0.02346,lr_multiplier:0.198,loss:4.279936790466309,entropy:3.497702121734619,explained_var_old:0.179,explained_var_new:0.217
# batch i:72, episode_len:32
# kl:0.02111,lr_multiplier:0.198,loss:4.269193172454834,entropy:3.484637975692749,explained_var_old:0.206,explained_var_new:0.232
# batch i:73, episode_len:37
# kl:0.03530,lr_multiplier:0.198,loss:4.268188953399658,entropy:3.4002573490142822,explained_var_old:0.142,explained_var_new:0.184
# batch i:74, episode_len:36
# kl:0.04261,lr_multiplier:0.132,loss:4.301044940948486,entropy:3.508246898651123,explained_var_old:0.158,explained_var_new:0.207
# batch i:75, episode_len:32
# kl:0.02491,lr_multiplier:0.132,loss:4.12484884262085,entropy:3.451887369155884,explained_var_old:0.295,explained_var_new:0.323
# batch i:76, episode_len:36
# kl:0.02131,lr_multiplier:0.132,loss:4.237711429595947,entropy:3.457797050476074,explained_var_old:0.253,explained_var_new:0.276
# batch i:77, episode_len:38
# kl:0.02383,lr_multiplier:0.132,loss:4.189963340759277,entropy:3.4483537673950195,explained_var_old:0.253,explained_var_new:0.277
# batch i:78, episode_len:44
# kl:0.01605,lr_multiplier:0.132,loss:4.255927562713623,entropy:3.4198153018951416,explained_var_old:0.163,explained_var_new:0.205
# batch i:79, episode_len:30
# kl:0.01633,lr_multiplier:0.132,loss:4.235803127288818,entropy:3.4886231422424316,explained_var_old:0.235,explained_var_new:0.256
# batch i:80, episode_len:31
# kl:0.02331,lr_multiplier:0.132,loss:4.194561004638672,entropy:3.4275646209716797,explained_var_old:0.222,explained_var_new:0.250
# batch i:81, episode_len:41
# kl:0.01521,lr_multiplier:0.132,loss:4.165684700012207,entropy:3.4570629596710205,explained_var_old:0.252,explained_var_new:0.271
# batch i:82, episode_len:30
# kl:0.02021,lr_multiplier:0.132,loss:4.225934982299805,entropy:3.4119138717651367,explained_var_old:0.237,explained_var_new:0.260
# batch i:83, episode_len:40
# kl:0.01849,lr_multiplier:0.132,loss:4.2399444580078125,entropy:3.47286319732666,explained_var_old:0.210,explained_var_new:0.239
# batch i:84, episode_len:46
# kl:0.01533,lr_multiplier:0.132,loss:4.1621174812316895,entropy:3.4289956092834473,explained_var_old:0.254,explained_var_new:0.292
# batch i:85, episode_len:30
# kl:0.01117,lr_multiplier:0.132,loss:4.322735786437988,entropy:3.512913227081299,explained_var_old:0.229,explained_var_new:0.253
# batch i:86, episode_len:56
# kl:0.01721,lr_multiplier:0.132,loss:4.0367279052734375,entropy:3.376391649246216,explained_var_old:0.316,explained_var_new:0.353
# batch i:87, episode_len:35
# kl:0.01529,lr_multiplier:0.132,loss:4.077139377593994,entropy:3.3694941997528076,explained_var_old:0.303,explained_var_new:0.336
# batch i:88, episode_len:42
# kl:0.01642,lr_multiplier:0.132,loss:4.122950077056885,entropy:3.3961734771728516,explained_var_old:0.270,explained_var_new:0.302
# batch i:89, episode_len:24
# kl:0.01578,lr_multiplier:0.132,loss:4.1104888916015625,entropy:3.431410789489746,explained_var_old:0.312,explained_var_new:0.352
# batch i:90, episode_len:36
# kl:0.01588,lr_multiplier:0.132,loss:3.9592525959014893,entropy:3.3091349601745605,explained_var_old:0.296,explained_var_new:0.339
# batch i:91, episode_len:36
# kl:0.01371,lr_multiplier:0.132,loss:4.0726165771484375,entropy:3.463888645172119,explained_var_old:0.366,explained_var_new:0.426
# batch i:92, episode_len:36
# kl:0.02307,lr_multiplier:0.132,loss:3.9685239791870117,entropy:3.306699752807617,explained_var_old:0.340,explained_var_new:0.418
# batch i:93, episode_len:46
# kl:0.01917,lr_multiplier:0.132,loss:3.962919235229492,entropy:3.3845839500427246,explained_var_old:0.396,explained_var_new:0.424
# batch i:94, episode_len:44
# kl:0.01220,lr_multiplier:0.132,loss:3.987729549407959,entropy:3.3160688877105713,explained_var_old:0.348,explained_var_new:0.390
# batch i:95, episode_len:31
# kl:0.01949,lr_multiplier:0.132,loss:3.950897216796875,entropy:3.356839656829834,explained_var_old:0.391,explained_var_new:0.424
# batch i:96, episode_len:36
# kl:0.01470,lr_multiplier:0.132,loss:3.9670259952545166,entropy:3.363616466522217,explained_var_old:0.374,explained_var_new:0.426
# batch i:97, episode_len:28
# kl:0.01267,lr_multiplier:0.132,loss:3.8975002765655518,entropy:3.305755615234375,explained_var_old:0.387,explained_var_new:0.422
# batch i:98, episode_len:34
# kl:0.01245,lr_multiplier:0.132,loss:3.828500986099243,entropy:3.3203890323638916,explained_var_old:0.471,explained_var_new:0.509
# batch i:99, episode_len:32
# kl:0.01419,lr_multiplier:0.132,loss:3.8699748516082764,entropy:3.342184543609619,explained_var_old:0.465,explained_var_new:0.493
# batch i:100, episode_len:46
# kl:0.01211,lr_multiplier:0.132,loss:3.899399518966675,entropy:3.3647818565368652,explained_var_old:0.406,explained_var_new:0.462
# current self-play batch: 100
# num_playouts:1000, win: 2, lose: 8, tie:0
# New best policy!!!!!!!!
# batch i:101, episode_len:46
# kl:0.01693,lr_multiplier:0.132,loss:3.8188345432281494,entropy:3.2838287353515625,explained_var_old:0.501,explained_var_new:0.549
# batch i:102, episode_len:49
# kl:0.02587,lr_multiplier:0.132,loss:4.0188307762146,entropy:3.3685302734375,explained_var_old:0.308,explained_var_new:0.371
# batch i:103, episode_len:38
# kl:0.02145,lr_multiplier:0.132,loss:3.97216796875,entropy:3.322129726409912,explained_var_old:0.415,explained_var_new:0.456
# batch i:104, episode_len:33
# kl:0.02219,lr_multiplier:0.132,loss:3.920196771621704,entropy:3.3572616577148438,explained_var_old:0.448,explained_var_new:0.492
# batch i:105, episode_len:24
# kl:0.01659,lr_multiplier:0.132,loss:3.8568880558013916,entropy:3.3181962966918945,explained_var_old:0.456,explained_var_new:0.496
# batch i:106, episode_len:44
# kl:0.01308,lr_multiplier:0.132,loss:3.826097011566162,entropy:3.3971240520477295,explained_var_old:0.543,explained_var_new:0.579
# batch i:107, episode_len:37
# kl:0.01438,lr_multiplier:0.132,loss:3.9821057319641113,entropy:3.396735668182373,explained_var_old:0.447,explained_var_new:0.483
# batch i:108, episode_len:30
# kl:0.01321,lr_multiplier:0.132,loss:3.7858104705810547,entropy:3.322211742401123,explained_var_old:0.507,explained_var_new:0.536
# batch i:109, episode_len:28
# kl:0.01663,lr_multiplier:0.132,loss:3.888829231262207,entropy:3.4206864833831787,explained_var_old:0.514,explained_var_new:0.550
# batch i:110, episode_len:34
# kl:0.00989,lr_multiplier:0.198,loss:3.8703882694244385,entropy:3.329573154449463,explained_var_old:0.475,explained_var_new:0.518
# batch i:111, episode_len:40
# kl:0.01717,lr_multiplier:0.198,loss:3.8181393146514893,entropy:3.393954038619995,explained_var_old:0.557,explained_var_new:0.587
# batch i:112, episode_len:28
# kl:0.01786,lr_multiplier:0.198,loss:3.8193001747131348,entropy:3.337203025817871,explained_var_old:0.528,explained_var_new:0.574
# batch i:113, episode_len:48
# kl:0.02338,lr_multiplier:0.198,loss:3.818274736404419,entropy:3.37009334564209,explained_var_old:0.505,explained_var_new:0.565
# batch i:114, episode_len:29
# kl:0.02507,lr_multiplier:0.198,loss:3.7366366386413574,entropy:3.314847469329834,explained_var_old:0.554,explained_var_new:0.601
# batch i:115, episode_len:48
# kl:0.02321,lr_multiplier:0.198,loss:3.832955837249756,entropy:3.360218048095703,explained_var_old:0.549,explained_var_new:0.581
# batch i:116, episode_len:32
# kl:0.02869,lr_multiplier:0.198,loss:3.761632204055786,entropy:3.4089713096618652,explained_var_old:0.599,explained_var_new:0.649
# batch i:117, episode_len:42
# kl:0.04017,lr_multiplier:0.132,loss:3.7412028312683105,entropy:3.3177475929260254,explained_var_old:0.580,explained_var_new:0.622
# batch i:118, episode_len:22
# kl:0.02534,lr_multiplier:0.132,loss:3.735041618347168,entropy:3.335829257965088,explained_var_old:0.606,explained_var_new:0.639
# batch i:119, episode_len:25
# kl:0.01619,lr_multiplier:0.132,loss:3.7447457313537598,entropy:3.3635315895080566,explained_var_old:0.587,explained_var_new:0.628
# batch i:120, episode_len:40
# kl:0.02286,lr_multiplier:0.132,loss:3.775041103363037,entropy:3.3332228660583496,explained_var_old:0.547,explained_var_new:0.585
# batch i:121, episode_len:34
# kl:0.01818,lr_multiplier:0.132,loss:3.7782018184661865,entropy:3.3219685554504395,explained_var_old:0.561,explained_var_new:0.603
# batch i:122, episode_len:35
# kl:0.01737,lr_multiplier:0.132,loss:3.663734197616577,entropy:3.244696617126465,explained_var_old:0.616,explained_var_new:0.649
# batch i:123, episode_len:36
# kl:0.01754,lr_multiplier:0.132,loss:3.792819023132324,entropy:3.3598756790161133,explained_var_old:0.543,explained_var_new:0.590
# batch i:124, episode_len:27
# kl:0.01800,lr_multiplier:0.132,loss:3.7996859550476074,entropy:3.342087745666504,explained_var_old:0.532,explained_var_new:0.594
# batch i:125, episode_len:38
# kl:0.02039,lr_multiplier:0.132,loss:3.9285812377929688,entropy:3.367600440979004,explained_var_old:0.409,explained_var_new:0.466
# batch i:126, episode_len:30
# kl:0.01571,lr_multiplier:0.132,loss:3.909937620162964,entropy:3.3878355026245117,explained_var_old:0.436,explained_var_new:0.516
# batch i:127, episode_len:36
# kl:0.01869,lr_multiplier:0.132,loss:3.858771562576294,entropy:3.3807387351989746,explained_var_old:0.537,explained_var_new:0.570
# batch i:128, episode_len:44
# kl:0.02802,lr_multiplier:0.132,loss:3.944465160369873,entropy:3.4109365940093994,explained_var_old:0.447,explained_var_new:0.513
# batch i:129, episode_len:32
# kl:0.02581,lr_multiplier:0.132,loss:3.8494808673858643,entropy:3.325989007949829,explained_var_old:0.431,explained_var_new:0.500
# batch i:130, episode_len:32
# kl:0.02381,lr_multiplier:0.132,loss:3.8639721870422363,entropy:3.3101577758789062,explained_var_old:0.446,explained_var_new:0.499
# batch i:131, episode_len:46
# kl:0.02033,lr_multiplier:0.132,loss:3.7305212020874023,entropy:3.3906357288360596,explained_var_old:0.590,explained_var_new:0.625
# batch i:132, episode_len:36
# kl:0.01616,lr_multiplier:0.132,loss:3.7872674465179443,entropy:3.320570945739746,explained_var_old:0.531,explained_var_new:0.593
# batch i:133, episode_len:46
# kl:0.01640,lr_multiplier:0.132,loss:3.8334414958953857,entropy:3.399104595184326,explained_var_old:0.593,explained_var_new:0.635
# batch i:134, episode_len:36
# kl:0.02186,lr_multiplier:0.132,loss:3.7815330028533936,entropy:3.340242862701416,explained_var_old:0.560,explained_var_new:0.597
# batch i:135, episode_len:28
# kl:0.02008,lr_multiplier:0.132,loss:3.8426926136016846,entropy:3.3734517097473145,explained_var_old:0.523,explained_var_new:0.572
# batch i:136, episode_len:54
# kl:0.02088,lr_multiplier:0.132,loss:3.79492449760437,entropy:3.4162302017211914,explained_var_old:0.584,explained_var_new:0.646
# batch i:137, episode_len:19
# kl:0.02559,lr_multiplier:0.132,loss:3.7842421531677246,entropy:3.3060812950134277,explained_var_old:0.514,explained_var_new:0.560
# batch i:138, episode_len:38
# kl:0.01991,lr_multiplier:0.132,loss:3.659231662750244,entropy:3.306957244873047,explained_var_old:0.616,explained_var_new:0.666
# batch i:139, episode_len:40
# kl:0.03001,lr_multiplier:0.132,loss:3.66430401802063,entropy:3.278474807739258,explained_var_old:0.644,explained_var_new:0.686
# batch i:140, episode_len:48
# kl:0.01977,lr_multiplier:0.132,loss:3.7338478565216064,entropy:3.4126410484313965,explained_var_old:0.674,explained_var_new:0.705
# batch i:141, episode_len:36
# kl:0.01893,lr_multiplier:0.132,loss:3.6690900325775146,entropy:3.2426679134368896,explained_var_old:0.593,explained_var_new:0.623
# batch i:142, episode_len:54
# kl:0.02734,lr_multiplier:0.132,loss:3.5777151584625244,entropy:3.2934534549713135,explained_var_old:0.708,explained_var_new:0.732
# batch i:143, episode_len:39
# kl:0.02217,lr_multiplier:0.132,loss:3.6566789150238037,entropy:3.2456705570220947,explained_var_old:0.623,explained_var_new:0.654
# batch i:144, episode_len:29
# kl:0.02617,lr_multiplier:0.132,loss:3.831517219543457,entropy:3.3354413509368896,explained_var_old:0.519,explained_var_new:0.548
# batch i:145, episode_len:38
# kl:0.02229,lr_multiplier:0.132,loss:3.7418129444122314,entropy:3.3189427852630615,explained_var_old:0.569,explained_var_new:0.617
# batch i:146, episode_len:36
# kl:0.03026,lr_multiplier:0.132,loss:3.7724456787109375,entropy:3.323308229446411,explained_var_old:0.549,explained_var_new:0.594
# batch i:147, episode_len:30
# kl:0.02111,lr_multiplier:0.132,loss:3.6578500270843506,entropy:3.2986762523651123,explained_var_old:0.602,explained_var_new:0.651
# batch i:148, episode_len:47
# kl:0.02649,lr_multiplier:0.132,loss:3.9555399417877197,entropy:3.411710739135742,explained_var_old:0.472,explained_var_new:0.504
# batch i:149, episode_len:34
# kl:0.02529,lr_multiplier:0.132,loss:3.8603811264038086,entropy:3.335357666015625,explained_var_old:0.498,explained_var_new:0.526
# batch i:150, episode_len:51
# kl:0.03748,lr_multiplier:0.132,loss:4.063049793243408,entropy:3.4044947624206543,explained_var_old:0.294,explained_var_new:0.345
# current self-play batch: 150
# num_playouts:1000, win: 2, lose: 8, tie:0
# batch i:151, episode_len:33
# kl:0.03771,lr_multiplier:0.132,loss:4.270511150360107,entropy:3.4744338989257812,explained_var_old:0.260,explained_var_new:0.280
# batch i:152, episode_len:36
# kl:0.03796,lr_multiplier:0.132,loss:4.107651233673096,entropy:3.402475357055664,explained_var_old:0.258,explained_var_new:0.309
# batch i:153, episode_len:26
# kl:0.02101,lr_multiplier:0.132,loss:4.015956401824951,entropy:3.3393337726593018,explained_var_old:0.274,explained_var_new:0.354
# batch i:154, episode_len:35
# kl:0.01862,lr_multiplier:0.132,loss:4.168659210205078,entropy:3.3276562690734863,explained_var_old:0.170,explained_var_new:0.206
# batch i:155, episode_len:23
# kl:0.02353,lr_multiplier:0.132,loss:4.112308025360107,entropy:3.365300416946411,explained_var_old:0.221,explained_var_new:0.275
# batch i:156, episode_len:40
# kl:0.01567,lr_multiplier:0.132,loss:4.0428466796875,entropy:3.3576555252075195,explained_var_old:0.292,explained_var_new:0.355
# batch i:157, episode_len:27
# kl:0.02812,lr_multiplier:0.132,loss:4.0883636474609375,entropy:3.3236074447631836,explained_var_old:0.205,explained_var_new:0.277
# batch i:158, episode_len:57
# kl:0.02365,lr_multiplier:0.132,loss:4.140608787536621,entropy:3.2877626419067383,explained_var_old:0.103,explained_var_new:0.189
# batch i:159, episode_len:30
# kl:0.01800,lr_multiplier:0.132,loss:4.1100993156433105,entropy:3.342484951019287,explained_var_old:0.194,explained_var_new:0.265
# batch i:160, episode_len:19
# kl:0.01805,lr_multiplier:0.132,loss:4.205097675323486,entropy:3.4262475967407227,explained_var_old:0.148,explained_var_new:0.234
# batch i:161, episode_len:34
# kl:0.01955,lr_multiplier:0.132,loss:4.132944107055664,entropy:3.3625197410583496,explained_var_old:0.183,explained_var_new:0.246
# batch i:162, episode_len:48
# kl:0.02411,lr_multiplier:0.132,loss:4.091619491577148,entropy:3.3374452590942383,explained_var_old:0.240,explained_var_new:0.301
# batch i:163, episode_len:30
# kl:0.01443,lr_multiplier:0.132,loss:3.9918808937072754,entropy:3.3414306640625,explained_var_old:0.283,explained_var_new:0.351
# batch i:164, episode_len:24
# kl:0.01873,lr_multiplier:0.132,loss:4.016975402832031,entropy:3.2900748252868652,explained_var_old:0.267,explained_var_new:0.314
# batch i:165, episode_len:40
# kl:0.02146,lr_multiplier:0.132,loss:4.018820285797119,entropy:3.305128574371338,explained_var_old:0.233,explained_var_new:0.295
# batch i:166, episode_len:34
# kl:0.01838,lr_multiplier:0.132,loss:4.035799980163574,entropy:3.346205472946167,explained_var_old:0.272,explained_var_new:0.338
# batch i:167, episode_len:38
# kl:0.02567,lr_multiplier:0.132,loss:4.020350456237793,entropy:3.332345962524414,explained_var_old:0.285,explained_var_new:0.349
# batch i:168, episode_len:21
# kl:0.02652,lr_multiplier:0.132,loss:3.9104576110839844,entropy:3.323091745376587,explained_var_old:0.373,explained_var_new:0.410
# batch i:169, episode_len:72
# kl:0.03478,lr_multiplier:0.132,loss:4.011651039123535,entropy:3.324793815612793,explained_var_old:0.289,explained_var_new:0.362
# batch i:170, episode_len:31
# kl:0.02490,lr_multiplier:0.132,loss:4.140209674835205,entropy:3.4186408519744873,explained_var_old:0.282,explained_var_new:0.336
# batch i:171, episode_len:28
# kl:0.02969,lr_multiplier:0.132,loss:4.014400005340576,entropy:3.318467855453491,explained_var_old:0.334,explained_var_new:0.406
# batch i:172, episode_len:30
# kl:0.01911,lr_multiplier:0.132,loss:4.105010032653809,entropy:3.4943735599517822,explained_var_old:0.350,explained_var_new:0.399
# batch i:173, episode_len:36
# kl:0.01536,lr_multiplier:0.132,loss:4.044744491577148,entropy:3.4363183975219727,explained_var_old:0.367,explained_var_new:0.429
# batch i:174, episode_len:45
# kl:0.03098,lr_multiplier:0.132,loss:3.958129644393921,entropy:3.296109199523926,explained_var_old:0.316,explained_var_new:0.365
# batch i:175, episode_len:34
# kl:0.02473,lr_multiplier:0.132,loss:3.8656084537506104,entropy:3.2480270862579346,explained_var_old:0.371,explained_var_new:0.426
# batch i:176, episode_len:34
# kl:0.02721,lr_multiplier:0.132,loss:4.02694845199585,entropy:3.334007501602173,explained_var_old:0.333,explained_var_new:0.379
# batch i:177, episode_len:34
# kl:0.02607,lr_multiplier:0.132,loss:3.963806390762329,entropy:3.26355242729187,explained_var_old:0.257,explained_var_new:0.321
# batch i:178, episode_len:26
# kl:0.02629,lr_multiplier:0.132,loss:3.9912309646606445,entropy:3.367493152618408,explained_var_old:0.364,explained_var_new:0.420
# batch i:179, episode_len:48
# kl:0.02260,lr_multiplier:0.132,loss:3.8680548667907715,entropy:3.2366843223571777,explained_var_old:0.375,explained_var_new:0.442
# batch i:180, episode_len:48
# kl:0.02330,lr_multiplier:0.132,loss:3.974982738494873,entropy:3.386636734008789,explained_var_old:0.362,explained_var_new:0.407
# batch i:181, episode_len:36
# kl:0.02986,lr_multiplier:0.132,loss:3.8484556674957275,entropy:3.3430745601654053,explained_var_old:0.445,explained_var_new:0.505
# batch i:182, episode_len:46
# kl:0.04491,lr_multiplier:0.088,loss:3.987356662750244,entropy:3.352487802505493,explained_var_old:0.385,explained_var_new:0.453
# batch i:183, episode_len:34
# kl:0.02671,lr_multiplier:0.088,loss:3.9681036472320557,entropy:3.366786003112793,explained_var_old:0.359,explained_var_new:0.393
# batch i:184, episode_len:34
# kl:0.02552,lr_multiplier:0.088,loss:4.003802299499512,entropy:3.330641984939575,explained_var_old:0.365,explained_var_new:0.396
# batch i:185, episode_len:47
# kl:0.02084,lr_multiplier:0.088,loss:3.948556423187256,entropy:3.353262186050415,explained_var_old:0.336,explained_var_new:0.380
# batch i:186, episode_len:17
# kl:0.01699,lr_multiplier:0.088,loss:3.877152919769287,entropy:3.248072862625122,explained_var_old:0.388,explained_var_new:0.428
# batch i:187, episode_len:48
# kl:0.01260,lr_multiplier:0.088,loss:3.889129877090454,entropy:3.3234505653381348,explained_var_old:0.440,explained_var_new:0.498
# batch i:188, episode_len:26
# kl:0.02044,lr_multiplier:0.088,loss:3.9627394676208496,entropy:3.385655164718628,explained_var_old:0.404,explained_var_new:0.438
# batch i:189, episode_len:57
# kl:0.01599,lr_multiplier:0.088,loss:3.960324287414551,entropy:3.3771800994873047,explained_var_old:0.417,explained_var_new:0.455
# batch i:190, episode_len:36
# kl:0.02168,lr_multiplier:0.088,loss:3.913506507873535,entropy:3.342751979827881,explained_var_old:0.418,explained_var_new:0.450
# batch i:191, episode_len:36
# kl:0.02101,lr_multiplier:0.088,loss:3.940063238143921,entropy:3.453909158706665,explained_var_old:0.492,explained_var_new:0.523
# batch i:192, episode_len:48
# kl:0.02133,lr_multiplier:0.088,loss:3.9096617698669434,entropy:3.343791961669922,explained_var_old:0.410,explained_var_new:0.459
# batch i:193, episode_len:36
# kl:0.01834,lr_multiplier:0.088,loss:3.9700100421905518,entropy:3.411278009414673,explained_var_old:0.427,explained_var_new:0.450
# batch i:194, episode_len:49
# kl:0.01937,lr_multiplier:0.088,loss:4.023751258850098,entropy:3.3980774879455566,explained_var_old:0.340,explained_var_new:0.394
# batch i:195, episode_len:53
# kl:0.01867,lr_multiplier:0.088,loss:4.1642961502075195,entropy:3.494687795639038,explained_var_old:0.343,explained_var_new:0.371
# batch i:196, episode_len:34
# kl:0.01746,lr_multiplier:0.088,loss:3.9963762760162354,entropy:3.3328771591186523,explained_var_old:0.324,explained_var_new:0.366
# batch i:197, episode_len:31
# kl:0.01760,lr_multiplier:0.088,loss:4.072044372558594,entropy:3.347546100616455,explained_var_old:0.204,explained_var_new:0.267
# batch i:198, episode_len:58
# kl:0.02023,lr_multiplier:0.088,loss:4.097999572753906,entropy:3.438145399093628,explained_var_old:0.315,explained_var_new:0.378
# batch i:199, episode_len:49
# kl:0.05246,lr_multiplier:0.088,loss:4.1038103103637695,entropy:3.390110492706299,explained_var_old:0.258,explained_var_new:0.296
# batch i:200, episode_len:34
# kl:0.02621,lr_multiplier:0.088,loss:4.016454219818115,entropy:3.388894557952881,explained_var_old:0.292,explained_var_new:0.346
# current self-play batch: 200
# num_playouts:1000, win: 4, lose: 6, tie:0
# New best policy!!!!!!!!
# batch i:201, episode_len:41
# kl:0.01905,lr_multiplier:0.088,loss:4.176591873168945,entropy:3.3867416381835938,explained_var_old:0.247,explained_var_new:0.289
# batch i:202, episode_len:32
# kl:0.01468,lr_multiplier:0.088,loss:4.040413856506348,entropy:3.3810720443725586,explained_var_old:0.292,explained_var_new:0.348
# batch i:203, episode_len:42
# kl:0.02036,lr_multiplier:0.088,loss:4.06568717956543,entropy:3.440080165863037,explained_var_old:0.321,explained_var_new:0.374
# batch i:204, episode_len:20
# kl:0.01699,lr_multiplier:0.088,loss:4.074997901916504,entropy:3.415619373321533,explained_var_old:0.327,explained_var_new:0.375
# batch i:205, episode_len:41
# kl:0.01893,lr_multiplier:0.088,loss:4.151493549346924,entropy:3.433532238006592,explained_var_old:0.279,explained_var_new:0.321
# batch i:206, episode_len:40
# kl:0.01970,lr_multiplier:0.088,loss:4.09412956237793,entropy:3.4159746170043945,explained_var_old:0.326,explained_var_new:0.375
# batch i:207, episode_len:25
# kl:0.01804,lr_multiplier:0.088,loss:4.128279209136963,entropy:3.4661061763763428,explained_var_old:0.333,explained_var_new:0.382
# batch i:208, episode_len:21
# kl:0.01723,lr_multiplier:0.088,loss:4.133397102355957,entropy:3.443704605102539,explained_var_old:0.280,explained_var_new:0.327
# batch i:209, episode_len:22
# kl:0.02117,lr_multiplier:0.088,loss:4.115006923675537,entropy:3.458235263824463,explained_var_old:0.282,explained_var_new:0.334
# batch i:210, episode_len:39
# kl:0.01429,lr_multiplier:0.088,loss:4.096607685089111,entropy:3.3573458194732666,explained_var_old:0.303,explained_var_new:0.347
# batch i:211, episode_len:34
# kl:0.02299,lr_multiplier:0.088,loss:4.136329650878906,entropy:3.471571922302246,explained_var_old:0.306,explained_var_new:0.335
# batch i:212, episode_len:40
# kl:0.01320,lr_multiplier:0.088,loss:4.036716461181641,entropy:3.3616538047790527,explained_var_old:0.272,explained_var_new:0.322
# batch i:213, episode_len:50
# kl:0.01808,lr_multiplier:0.088,loss:4.167263031005859,entropy:3.2963786125183105,explained_var_old:0.143,explained_var_new:0.203
# batch i:214, episode_len:24
# kl:0.02112,lr_multiplier:0.088,loss:4.124012470245361,entropy:3.3429696559906006,explained_var_old:0.228,explained_var_new:0.267
# batch i:215, episode_len:54
# kl:0.03273,lr_multiplier:0.088,loss:4.128477573394775,entropy:3.386174201965332,explained_var_old:0.251,explained_var_new:0.293
# batch i:216, episode_len:35
# kl:0.03087,lr_multiplier:0.088,loss:4.2256550788879395,entropy:3.483306884765625,explained_var_old:0.203,explained_var_new:0.260
# batch i:217, episode_len:28
# kl:0.02229,lr_multiplier:0.088,loss:4.197238922119141,entropy:3.4204533100128174,explained_var_old:0.247,explained_var_new:0.286
# batch i:218, episode_len:57
# kl:0.02296,lr_multiplier:0.088,loss:4.185275077819824,entropy:3.4282901287078857,explained_var_old:0.217,explained_var_new:0.271
# batch i:219, episode_len:50
# kl:0.02129,lr_multiplier:0.088,loss:4.103124141693115,entropy:3.4259276390075684,explained_var_old:0.273,explained_var_new:0.347
# batch i:220, episode_len:36
# kl:0.02087,lr_multiplier:0.088,loss:4.208043575286865,entropy:3.3992390632629395,explained_var_old:0.217,explained_var_new:0.270
# batch i:221, episode_len:58
# kl:0.02136,lr_multiplier:0.088,loss:4.208272933959961,entropy:3.5178604125976562,explained_var_old:0.258,explained_var_new:0.313
# batch i:222, episode_len:21
# kl:0.03451,lr_multiplier:0.088,loss:4.110918998718262,entropy:3.4033029079437256,explained_var_old:0.277,explained_var_new:0.327
# batch i:223, episode_len:40
# kl:0.02964,lr_multiplier:0.088,loss:4.077271461486816,entropy:3.4274797439575195,explained_var_old:0.269,explained_var_new:0.342
# batch i:224, episode_len:23
# kl:0.02625,lr_multiplier:0.088,loss:4.149407863616943,entropy:3.4704034328460693,explained_var_old:0.292,explained_var_new:0.354
# batch i:225, episode_len:36
# kl:0.03933,lr_multiplier:0.088,loss:3.973551034927368,entropy:3.372779130935669,explained_var_old:0.364,explained_var_new:0.424
# batch i:226, episode_len:25
# kl:0.01915,lr_multiplier:0.088,loss:3.980125904083252,entropy:3.265763998031616,explained_var_old:0.327,explained_var_new:0.368
# batch i:227, episode_len:29
# kl:0.02081,lr_multiplier:0.088,loss:4.084731101989746,entropy:3.500256299972534,explained_var_old:0.316,explained_var_new:0.373
# batch i:228, episode_len:45
# kl:0.02097,lr_multiplier:0.088,loss:4.023172378540039,entropy:3.4242312908172607,explained_var_old:0.425,explained_var_new:0.470
# batch i:229, episode_len:57
# kl:0.01580,lr_multiplier:0.088,loss:3.9762041568756104,entropy:3.3676984310150146,explained_var_old:0.351,explained_var_new:0.401
# batch i:230, episode_len:23
# kl:0.01792,lr_multiplier:0.088,loss:3.9694788455963135,entropy:3.482497215270996,explained_var_old:0.427,explained_var_new:0.476
# batch i:231, episode_len:60
# kl:0.02157,lr_multiplier:0.088,loss:4.05764627456665,entropy:3.400296211242676,explained_var_old:0.343,explained_var_new:0.385
# batch i:232, episode_len:59
# kl:0.02388,lr_multiplier:0.088,loss:4.078914165496826,entropy:3.4751410484313965,explained_var_old:0.403,explained_var_new:0.449
# batch i:233, episode_len:38
# kl:0.02263,lr_multiplier:0.088,loss:4.138812065124512,entropy:3.435068130493164,explained_var_old:0.248,explained_var_new:0.302
# batch i:234, episode_len:48
# kl:0.03039,lr_multiplier:0.088,loss:4.181929588317871,entropy:3.4147024154663086,explained_var_old:0.217,explained_var_new:0.276
# batch i:235, episode_len:32
# kl:0.03043,lr_multiplier:0.088,loss:4.077637195587158,entropy:3.395609140396118,explained_var_old:0.330,explained_var_new:0.366
# batch i:236, episode_len:29
# kl:0.02844,lr_multiplier:0.088,loss:4.077103137969971,entropy:3.395900249481201,explained_var_old:0.293,explained_var_new:0.345
# batch i:237, episode_len:35
# kl:0.02716,lr_multiplier:0.088,loss:4.056838035583496,entropy:3.4196858406066895,explained_var_old:0.328,explained_var_new:0.389
# batch i:238, episode_len:30
# kl:0.01877,lr_multiplier:0.088,loss:4.109992980957031,entropy:3.452538013458252,explained_var_old:0.332,explained_var_new:0.384
# batch i:239, episode_len:20
# kl:0.02112,lr_multiplier:0.088,loss:4.010281085968018,entropy:3.4385364055633545,explained_var_old:0.402,explained_var_new:0.448
# batch i:240, episode_len:24
# kl:0.02353,lr_multiplier:0.088,loss:3.9903202056884766,entropy:3.4029934406280518,explained_var_old:0.379,explained_var_new:0.428
# batch i:241, episode_len:36
# kl:0.02218,lr_multiplier:0.088,loss:4.077363967895508,entropy:3.396329402923584,explained_var_old:0.328,explained_var_new:0.391
# batch i:242, episode_len:41
# kl:0.01660,lr_multiplier:0.088,loss:4.087447643280029,entropy:3.443265914916992,explained_var_old:0.291,explained_var_new:0.374
# batch i:243, episode_len:29
# kl:0.01402,lr_multiplier:0.088,loss:4.05198860168457,entropy:3.4537110328674316,explained_var_old:0.364,explained_var_new:0.415
# batch i:244, episode_len:19
# kl:0.01669,lr_multiplier:0.088,loss:3.91723370552063,entropy:3.4339282512664795,explained_var_old:0.405,explained_var_new:0.455
# batch i:245, episode_len:31
# kl:0.01674,lr_multiplier:0.088,loss:3.8558599948883057,entropy:3.3216114044189453,explained_var_old:0.473,explained_var_new:0.508
# batch i:246, episode_len:39
# kl:0.01402,lr_multiplier:0.088,loss:3.8922359943389893,entropy:3.329400062561035,explained_var_old:0.401,explained_var_new:0.446
# batch i:247, episode_len:31
# kl:0.01874,lr_multiplier:0.088,loss:4.005016803741455,entropy:3.422330141067505,explained_var_old:0.368,explained_var_new:0.399
# batch i:248, episode_len:37
# kl:0.02034,lr_multiplier:0.088,loss:4.0077385902404785,entropy:3.322037696838379,explained_var_old:0.333,explained_var_new:0.383
# batch i:249, episode_len:43
# kl:0.01763,lr_multiplier:0.088,loss:4.039518356323242,entropy:3.3740732669830322,explained_var_old:0.344,explained_var_new:0.390
# batch i:250, episode_len:47
# kl:0.02035,lr_multiplier:0.088,loss:4.024225234985352,entropy:3.423201084136963,explained_var_old:0.330,explained_var_new:0.386
# current self-play batch: 250
# num_playouts:1000, win: 5, lose: 5, tie:0
# New best policy!!!!!!!!
# batch i:251, episode_len:39
# kl:0.02266,lr_multiplier:0.088,loss:4.009566307067871,entropy:3.3475112915039062,explained_var_old:0.345,explained_var_new:0.396
# batch i:252, episode_len:29
# kl:0.03549,lr_multiplier:0.088,loss:4.027411460876465,entropy:3.46012020111084,explained_var_old:0.358,explained_var_new:0.394
# batch i:253, episode_len:52
# kl:0.03119,lr_multiplier:0.088,loss:3.8992161750793457,entropy:3.367854118347168,explained_var_old:0.439,explained_var_new:0.511
# batch i:254, episode_len:29
# kl:0.01642,lr_multiplier:0.088,loss:3.975327253341675,entropy:3.41098690032959,explained_var_old:0.403,explained_var_new:0.457
# batch i:255, episode_len:18
# kl:0.01867,lr_multiplier:0.088,loss:3.8839831352233887,entropy:3.357130765914917,explained_var_old:0.443,explained_var_new:0.502
# batch i:256, episode_len:53
# kl:0.01491,lr_multiplier:0.088,loss:3.916865348815918,entropy:3.389770030975342,explained_var_old:0.427,explained_var_new:0.486
# batch i:257, episode_len:23
# kl:0.01628,lr_multiplier:0.088,loss:3.9060709476470947,entropy:3.35337233543396,explained_var_old:0.478,explained_var_new:0.507
# batch i:258, episode_len:47
# kl:0.01424,lr_multiplier:0.088,loss:3.9181911945343018,entropy:3.3473336696624756,explained_var_old:0.427,explained_var_new:0.463
# batch i:259, episode_len:57
# kl:0.01687,lr_multiplier:0.088,loss:3.933150053024292,entropy:3.393536329269409,explained_var_old:0.466,explained_var_new:0.493
# batch i:260, episode_len:13
# kl:0.01332,lr_multiplier:0.088,loss:3.8724606037139893,entropy:3.384537696838379,explained_var_old:0.491,explained_var_new:0.531
# batch i:261, episode_len:62
# kl:0.01949,lr_multiplier:0.088,loss:3.96498703956604,entropy:3.3797991275787354,explained_var_old:0.356,explained_var_new:0.431
# batch i:262, episode_len:29
# kl:0.02959,lr_multiplier:0.088,loss:3.999596118927002,entropy:3.3350772857666016,explained_var_old:0.370,explained_var_new:0.421
# batch i:263, episode_len:56
# kl:0.02632,lr_multiplier:0.088,loss:3.9552834033966064,entropy:3.3965532779693604,explained_var_old:0.358,explained_var_new:0.431
# batch i:264, episode_len:25
# kl:0.02528,lr_multiplier:0.088,loss:3.8760783672332764,entropy:3.357593059539795,explained_var_old:0.381,explained_var_new:0.466
# batch i:265, episode_len:11
# kl:0.01312,lr_multiplier:0.088,loss:3.8707940578460693,entropy:3.327479839324951,explained_var_old:0.448,explained_var_new:0.496
# batch i:266, episode_len:15
# kl:0.01923,lr_multiplier:0.088,loss:3.895585536956787,entropy:3.3546533584594727,explained_var_old:0.429,explained_var_new:0.465
# batch i:267, episode_len:33
# kl:0.02024,lr_multiplier:0.088,loss:3.8919146060943604,entropy:3.336574077606201,explained_var_old:0.424,explained_var_new:0.492
# batch i:268, episode_len:21
# kl:0.03254,lr_multiplier:0.088,loss:3.8193554878234863,entropy:3.3995370864868164,explained_var_old:0.518,explained_var_new:0.565
# batch i:269, episode_len:46
# kl:0.01922,lr_multiplier:0.088,loss:3.891771078109741,entropy:3.330587387084961,explained_var_old:0.426,explained_var_new:0.466
# batch i:270, episode_len:49
# kl:0.02176,lr_multiplier:0.088,loss:3.8360610008239746,entropy:3.2744040489196777,explained_var_old:0.466,explained_var_new:0.513
# batch i:271, episode_len:29
# kl:0.02143,lr_multiplier:0.088,loss:3.928123950958252,entropy:3.3535757064819336,explained_var_old:0.404,explained_var_new:0.427
# batch i:272, episode_len:29
# kl:0.02326,lr_multiplier:0.088,loss:3.793060779571533,entropy:3.2488155364990234,explained_var_old:0.476,explained_var_new:0.525
# batch i:273, episode_len:43
# kl:0.02664,lr_multiplier:0.088,loss:3.9099695682525635,entropy:3.3761463165283203,explained_var_old:0.388,explained_var_new:0.436
# batch i:274, episode_len:21
# kl:0.01973,lr_multiplier:0.088,loss:3.941899061203003,entropy:3.2845492362976074,explained_var_old:0.360,explained_var_new:0.400
# batch i:275, episode_len:55
# kl:0.02026,lr_multiplier:0.088,loss:3.8319225311279297,entropy:3.243699550628662,explained_var_old:0.407,explained_var_new:0.456
# batch i:276, episode_len:38
# kl:0.02201,lr_multiplier:0.088,loss:3.689424991607666,entropy:3.2682242393493652,explained_var_old:0.523,explained_var_new:0.568
# batch i:277, episode_len:41
# kl:0.01606,lr_multiplier:0.088,loss:3.8668155670166016,entropy:3.309298515319824,explained_var_old:0.491,explained_var_new:0.537
# batch i:278, episode_len:38
# kl:0.02816,lr_multiplier:0.088,loss:3.8052570819854736,entropy:3.313462018966675,explained_var_old:0.463,explained_var_new:0.510
# batch i:279, episode_len:40
# kl:0.02060,lr_multiplier:0.088,loss:3.9182465076446533,entropy:3.290379047393799,explained_var_old:0.327,explained_var_new:0.396
# batch i:280, episode_len:25
# kl:0.01629,lr_multiplier:0.088,loss:3.8338258266448975,entropy:3.3176496028900146,explained_var_old:0.420,explained_var_new:0.469
# batch i:281, episode_len:26
# kl:0.02146,lr_multiplier:0.088,loss:3.9904518127441406,entropy:3.328176975250244,explained_var_old:0.277,explained_var_new:0.330
# batch i:282, episode_len:15
# kl:0.01563,lr_multiplier:0.088,loss:3.9473047256469727,entropy:3.327622413635254,explained_var_old:0.326,explained_var_new:0.374
# batch i:283, episode_len:29
# kl:0.02204,lr_multiplier:0.088,loss:4.025492191314697,entropy:3.3898348808288574,explained_var_old:0.342,explained_var_new:0.387
# batch i:284, episode_len:40
# kl:0.02880,lr_multiplier:0.088,loss:4.024307727813721,entropy:3.3148508071899414,explained_var_old:0.283,explained_var_new:0.358
# batch i:285, episode_len:31
# kl:0.02739,lr_multiplier:0.088,loss:3.963172674179077,entropy:3.3512508869171143,explained_var_old:0.349,explained_var_new:0.391
# batch i:286, episode_len:23
# kl:0.02490,lr_multiplier:0.088,loss:4.012213230133057,entropy:3.3525495529174805,explained_var_old:0.312,explained_var_new:0.360
# batch i:287, episode_len:54
# kl:0.02088,lr_multiplier:0.088,loss:3.9905190467834473,entropy:3.2576119899749756,explained_var_old:0.280,explained_var_new:0.340
# batch i:288, episode_len:31
# kl:0.03308,lr_multiplier:0.088,loss:3.9898757934570312,entropy:3.320845127105713,explained_var_old:0.304,explained_var_new:0.359
# batch i:289, episode_len:28
# kl:0.02099,lr_multiplier:0.088,loss:3.9798405170440674,entropy:3.335054636001587,explained_var_old:0.269,explained_var_new:0.325
# batch i:290, episode_len:26
# kl:0.02264,lr_multiplier:0.088,loss:4.011826515197754,entropy:3.2901153564453125,explained_var_old:0.241,explained_var_new:0.297
# batch i:291, episode_len:21
# kl:0.02242,lr_multiplier:0.088,loss:3.963019847869873,entropy:3.284553050994873,explained_var_old:0.317,explained_var_new:0.364
# batch i:292, episode_len:17
# kl:0.02883,lr_multiplier:0.088,loss:3.959751844406128,entropy:3.3528122901916504,explained_var_old:0.319,explained_var_new:0.360
# batch i:293, episode_len:17
# kl:0.02363,lr_multiplier:0.088,loss:3.954899787902832,entropy:3.327941417694092,explained_var_old:0.341,explained_var_new:0.401
# batch i:294, episode_len:11
# kl:0.01844,lr_multiplier:0.088,loss:4.02065372467041,entropy:3.335514545440674,explained_var_old:0.323,explained_var_new:0.355
# batch i:295, episode_len:17
# kl:0.02064,lr_multiplier:0.088,loss:3.9115676879882812,entropy:3.3138656616210938,explained_var_old:0.347,explained_var_new:0.405
# batch i:296, episode_len:23
# kl:0.01615,lr_multiplier:0.088,loss:3.9200491905212402,entropy:3.3597867488861084,explained_var_old:0.424,explained_var_new:0.455
# batch i:297, episode_len:13
# kl:0.01794,lr_multiplier:0.088,loss:3.863564968109131,entropy:3.3181087970733643,explained_var_old:0.382,explained_var_new:0.438
# batch i:298, episode_len:15
# kl:0.02650,lr_multiplier:0.088,loss:3.8699381351470947,entropy:3.2885544300079346,explained_var_old:0.448,explained_var_new:0.486
# batch i:299, episode_len:28
# kl:0.02941,lr_multiplier:0.088,loss:3.900266170501709,entropy:3.3207194805145264,explained_var_old:0.361,explained_var_new:0.414
# batch i:300, episode_len:29
# kl:0.01515,lr_multiplier:0.088,loss:4.074583053588867,entropy:3.3097572326660156,explained_var_old:0.300,explained_var_new:0.338
# current self-play batch: 300
# num_playouts:1000, win: 6, lose: 4, tie:0
# New best policy!!!!!!!!
# batch i:301, episode_len:35
# kl:0.01449,lr_multiplier:0.088,loss:3.9640560150146484,entropy:3.3293190002441406,explained_var_old:0.290,explained_var_new:0.346
# batch i:302, episode_len:40
# kl:0.02284,lr_multiplier:0.088,loss:3.963423728942871,entropy:3.241145372390747,explained_var_old:0.271,explained_var_new:0.331
# batch i:303, episode_len:15
# kl:0.02091,lr_multiplier:0.088,loss:3.901262044906616,entropy:3.3255362510681152,explained_var_old:0.361,explained_var_new:0.418
# batch i:304, episode_len:21
# kl:0.01953,lr_multiplier:0.088,loss:3.8650784492492676,entropy:3.2626962661743164,explained_var_old:0.314,explained_var_new:0.403
# batch i:305, episode_len:25
# ...
# kl:0.01528,lr_multiplier:0.088,loss:3.2832953929901123,entropy:2.6671805381774902,explained_var_old:0.347,explained_var_new:0.416
# batch i:598, episode_len:23
# kl:0.02342,lr_multiplier:0.088,loss:3.334411382675171,entropy:2.7999472618103027,explained_var_old:0.361,explained_var_new:0.407
# batch i:599, episode_len:23
# kl:0.01879,lr_multiplier:0.088,loss:3.2763161659240723,entropy:2.6891088485717773,explained_var_old:0.402,explained_var_new:0.467
# batch i:600, episode_len:15
# kl:0.01967,lr_multiplier:0.088,loss:3.4368131160736084,entropy:2.8154842853546143,explained_var_old:0.339,explained_var_new:0.411
# current self-play batch: 600
# num_playouts:3000, win: 8, lose: 2, tie:0
# New best policy!!!!!!!!
# batch i:601, episode_len:13
# kl:0.02236,lr_multiplier:0.088,loss:3.275531053543091,entropy:2.6717491149902344,explained_var_old:0.411,explained_var_new:0.461
# batch i:602, episode_len:25
# kl:0.01747,lr_multiplier:0.088,loss:3.3707034587860107,entropy:2.7945363521575928,explained_var_old:0.353,explained_var_new:0.413
# batch i:603, episode_len:40
# kl:0.01502,lr_multiplier:0.088,loss:3.4550046920776367,entropy:2.750732421875,explained_var_old:0.221,explained_var_new:0.310
# batch i:604, episode_len:62
# kl:0.01564,lr_multiplier:0.088,loss:3.425694465637207,entropy:2.7732372283935547,explained_var_old:0.348,explained_var_new:0.397
# batch i:605, episode_len:43
# kl:0.02366,lr_multiplier:0.088,loss:3.5194623470306396,entropy:2.809998035430908,explained_var_old:0.323,explained_var_new:0.384
# batch i:606, episode_len:21
# kl:0.01377,lr_multiplier:0.088,loss:3.447385549545288,entropy:2.8174757957458496,explained_var_old:0.352,explained_var_new:0.431
# batch i:607, episode_len:23
# kl:0.01695,lr_multiplier:0.088,loss:3.363243818283081,entropy:2.8174614906311035,explained_var_old:0.389,explained_var_new:0.451
# batch i:608, episode_len:27
# kl:0.01466,lr_multiplier:0.088,loss:3.401310443878174,entropy:2.688926935195923,explained_var_old:0.291,explained_var_new:0.349
# batch i:609, episode_len:18
# kl:0.01504,lr_multiplier:0.088,loss:3.479775905609131,entropy:2.797699213027954,explained_var_old:0.312,explained_var_new:0.372
# batch i:610, episode_len:28
# kl:0.01748,lr_multiplier:0.088,loss:3.5415804386138916,entropy:2.978987693786621,explained_var_old:0.362,explained_var_new:0.429
# batch i:611, episode_len:34
# kl:0.02644,lr_multiplier:0.088,loss:3.5163583755493164,entropy:2.8700671195983887,explained_var_old:0.361,explained_var_new:0.408
# batch i:612, episode_len:12
# kl:0.03028,lr_multiplier:0.088,loss:3.4438319206237793,entropy:2.8719723224639893,explained_var_old:0.358,explained_var_new:0.425
# batch i:613, episode_len:22
# kl:0.03530,lr_multiplier:0.088,loss:3.3500659465789795,entropy:2.7270209789276123,explained_var_old:0.399,explained_var_new:0.443
# batch i:614, episode_len:21
# kl:0.03006,lr_multiplier:0.088,loss:3.3943533897399902,entropy:2.8609418869018555,explained_var_old:0.433,explained_var_new:0.492
# batch i:615, episode_len:13
# kl:0.01855,lr_multiplier:0.088,loss:3.3871171474456787,entropy:2.8219244480133057,explained_var_old:0.373,explained_var_new:0.439
# batch i:616, episode_len:26
# kl:0.01818,lr_multiplier:0.088,loss:3.4259350299835205,entropy:2.878857135772705,explained_var_old:0.401,explained_var_new:0.461
# batch i:617, episode_len:28
# kl:0.01656,lr_multiplier:0.088,loss:3.395902395248413,entropy:2.809793472290039,explained_var_old:0.429,explained_var_new:0.511
# batch i:618, episode_len:16
# kl:0.02696,lr_multiplier:0.088,loss:3.489729642868042,entropy:2.941891670227051,explained_var_old:0.378,explained_var_new:0.441
# batch i:619, episode_len:15
# kl:0.03820,lr_multiplier:0.088,loss:3.3422043323516846,entropy:2.7361912727355957,explained_var_old:0.441,explained_var_new:0.473
# batch i:620, episode_len:13
# kl:0.03784,lr_multiplier:0.088,loss:3.2812533378601074,entropy:2.827108860015869,explained_var_old:0.414,explained_var_new:0.475
# batch i:621, episode_len:12
# kl:0.03678,lr_multiplier:0.088,loss:3.2902932167053223,entropy:2.8014893531799316,explained_var_old:0.464,explained_var_new:0.512
# batch i:622, episode_len:38
# kl:0.05730,lr_multiplier:0.088,loss:3.4822182655334473,entropy:2.9216203689575195,explained_var_old:0.413,explained_var_new:0.469
# batch i:623, episode_len:34
# kl:0.03403,lr_multiplier:0.088,loss:3.464128255844116,entropy:2.855664014816284,explained_var_old:0.371,explained_var_new:0.425
# batch i:624, episode_len:13
# kl:0.01833,lr_multiplier:0.088,loss:3.448258876800537,entropy:2.840853214263916,explained_var_old:0.384,explained_var_new:0.440
# batch i:625, episode_len:26
# kl:0.01108,lr_multiplier:0.088,loss:3.3619232177734375,entropy:2.78184175491333,explained_var_old:0.410,explained_var_new:0.466
# batch i:626, episode_len:24
# kl:0.01189,lr_multiplier:0.088,loss:3.4650654792785645,entropy:2.874589443206787,explained_var_old:0.421,explained_var_new:0.459
# batch i:627, episode_len:62
# kl:0.02245,lr_multiplier:0.088,loss:3.3555634021759033,entropy:2.865142345428467,explained_var_old:0.466,explained_var_new:0.506
# batch i:628, episode_len:39
# kl:0.01404,lr_multiplier:0.088,loss:3.442932367324829,entropy:2.8992342948913574,explained_var_old:0.414,explained_var_new:0.473
# batch i:629, episode_len:11
# kl:0.01562,lr_multiplier:0.088,loss:3.4228150844573975,entropy:2.866746664047241,explained_var_old:0.352,explained_var_new:0.444
# batch i:630, episode_len:13
# kl:0.01288,lr_multiplier:0.088,loss:3.401580333709717,entropy:2.867344379425049,explained_var_old:0.423,explained_var_new:0.466
# batch i:631, episode_len:14
# kl:0.01305,lr_multiplier:0.088,loss:3.4882454872131348,entropy:2.840941905975342,explained_var_old:0.370,explained_var_new:0.445
# batch i:632, episode_len:23
# kl:0.01300,lr_multiplier:0.088,loss:3.420516014099121,entropy:2.8508026599884033,explained_var_old:0.419,explained_var_new:0.472
# batch i:633, episode_len:14
# kl:0.01118,lr_multiplier:0.088,loss:3.482616662979126,entropy:2.905630111694336,explained_var_old:0.391,explained_var_new:0.440
# batch i:634, episode_len:59
# kl:0.01144,lr_multiplier:0.088,loss:3.5078887939453125,entropy:2.855351209640503,explained_var_old:0.282,explained_var_new:0.368
# batch i:635, episode_len:28
# kl:0.01944,lr_multiplier:0.088,loss:3.595881462097168,entropy:2.9752607345581055,explained_var_old:0.333,explained_var_new:0.387
# batch i:636, episode_len:16
# kl:0.01804,lr_multiplier:0.088,loss:3.4799106121063232,entropy:2.860736608505249,explained_var_old:0.357,explained_var_new:0.448
# batch i:637, episode_len:18
# kl:0.01647,lr_multiplier:0.088,loss:3.481576442718506,entropy:2.829890727996826,explained_var_old:0.410,explained_var_new:0.444
# batch i:638, episode_len:21
# kl:0.03544,lr_multiplier:0.088,loss:3.477530002593994,entropy:2.9764089584350586,explained_var_old:0.309,explained_var_new:0.399
# batch i:639, episode_len:33
# kl:0.02549,lr_multiplier:0.088,loss:3.452374219894409,entropy:2.832308769226074,explained_var_old:0.383,explained_var_new:0.425
# batch i:640, episode_len:11
# kl:0.01126,lr_multiplier:0.088,loss:3.5750935077667236,entropy:2.924696207046509,explained_var_old:0.340,explained_var_new:0.387
# batch i:641, episode_len:20
# kl:0.00818,lr_multiplier:0.132,loss:3.5783209800720215,entropy:2.9080140590667725,explained_var_old:0.293,explained_var_new:0.365
# batch i:642, episode_len:27
# kl:0.02060,lr_multiplier:0.132,loss:3.4534544944763184,entropy:2.8814234733581543,explained_var_old:0.346,explained_var_new:0.439
# batch i:643, episode_len:15
# kl:0.02269,lr_multiplier:0.132,loss:3.463743209838867,entropy:2.901545524597168,explained_var_old:0.366,explained_var_new:0.430
# batch i:644, episode_len:27
# kl:0.01831,lr_multiplier:0.132,loss:3.511543035507202,entropy:2.9042327404022217,explained_var_old:0.382,explained_var_new:0.446
# batch i:645, episode_len:23
# kl:0.02308,lr_multiplier:0.132,loss:3.476926565170288,entropy:2.9100122451782227,explained_var_old:0.353,explained_var_new:0.461
# batch i:646, episode_len:20
# kl:0.01894,lr_multiplier:0.132,loss:3.3790547847747803,entropy:2.8316454887390137,explained_var_old:0.417,explained_var_new:0.482
# batch i:647, episode_len:17
# kl:0.02363,lr_multiplier:0.132,loss:3.56123948097229,entropy:2.957294464111328,explained_var_old:0.381,explained_var_new:0.445
# batch i:648, episode_len:42
# kl:0.02013,lr_multiplier:0.132,loss:3.635215997695923,entropy:2.9755680561065674,explained_var_old:0.297,explained_var_new:0.372
# batch i:649, episode_len:26
# kl:0.02432,lr_multiplier:0.132,loss:3.6785807609558105,entropy:3.0035483837127686,explained_var_old:0.275,explained_var_new:0.341
# batch i:650, episode_len:13
# kl:0.02385,lr_multiplier:0.132,loss:3.511958122253418,entropy:2.940035343170166,explained_var_old:0.362,explained_var_new:0.424
# current self-play batch: 650
# num_playouts:3000, win: 6, lose: 4, tie:0
# batch i:651, episode_len:25
# kl:0.02273,lr_multiplier:0.132,loss:3.5273451805114746,entropy:2.947628974914551,explained_var_old:0.400,explained_var_new:0.456
# batch i:652, episode_len:20
# kl:0.02696,lr_multiplier:0.132,loss:3.5515658855438232,entropy:3.0208821296691895,explained_var_old:0.369,explained_var_new:0.436
# batch i:653, episode_len:60
# kl:0.02643,lr_multiplier:0.132,loss:3.448890209197998,entropy:2.8697962760925293,explained_var_old:0.418,explained_var_new:0.494
# batch i:654, episode_len:29
# kl:0.02092,lr_multiplier:0.132,loss:3.6060280799865723,entropy:2.927607297897339,explained_var_old:0.313,explained_var_new:0.385
# batch i:655, episode_len:29
# kl:0.01931,lr_multiplier:0.132,loss:3.6633071899414062,entropy:3.0381898880004883,explained_var_old:0.286,explained_var_new:0.368
# batch i:656, episode_len:41
# kl:0.02845,lr_multiplier:0.132,loss:3.6751465797424316,entropy:2.995539665222168,explained_var_old:0.251,explained_var_new:0.359
# batch i:657, episode_len:49
# kl:0.04086,lr_multiplier:0.088,loss:3.7327287197113037,entropy:3.003039836883545,explained_var_old:0.162,explained_var_new:0.280
# batch i:658, episode_len:34
# kl:0.02677,lr_multiplier:0.088,loss:3.763836622238159,entropy:2.972275733947754,explained_var_old:0.245,explained_var_new:0.308
# batch i:659, episode_len:37
# kl:0.02423,lr_multiplier:0.088,loss:3.843630313873291,entropy:3.052851676940918,explained_var_old:0.129,explained_var_new:0.220
# batch i:660, episode_len:39
# kl:0.01776,lr_multiplier:0.088,loss:3.8089559078216553,entropy:3.1536333560943604,explained_var_old:0.293,explained_var_new:0.340
# batch i:661, episode_len:12
# kl:0.03160,lr_multiplier:0.088,loss:3.7935924530029297,entropy:3.035031318664551,explained_var_old:0.249,explained_var_new:0.335
# batch i:662, episode_len:23
# kl:0.02303,lr_multiplier:0.088,loss:3.7219185829162598,entropy:3.1162586212158203,explained_var_old:0.282,explained_var_new:0.333
# batch i:663, episode_len:11
# kl:0.02059,lr_multiplier:0.088,loss:3.764622926712036,entropy:3.0366008281707764,explained_var_old:0.250,explained_var_new:0.301
# batch i:664, episode_len:23
# kl:0.02751,lr_multiplier:0.088,loss:3.7711727619171143,entropy:3.0377321243286133,explained_var_old:0.290,explained_var_new:0.345
# batch i:665, episode_len:32
# kl:0.02440,lr_multiplier:0.088,loss:3.820024013519287,entropy:3.179267406463623,explained_var_old:0.328,explained_var_new:0.375
# batch i:666, episode_len:13
# kl:0.02727,lr_multiplier:0.088,loss:3.7337608337402344,entropy:3.0709662437438965,explained_var_old:0.287,explained_var_new:0.349
# batch i:667, episode_len:24
# kl:0.03478,lr_multiplier:0.088,loss:3.6771597862243652,entropy:3.0990328788757324,explained_var_old:0.354,explained_var_new:0.414
# batch i:668, episode_len:16
# kl:0.02224,lr_multiplier:0.088,loss:3.861518621444702,entropy:3.193385601043701,explained_var_old:0.318,explained_var_new:0.385
# batch i:669, episode_len:18
# kl:0.01059,lr_multiplier:0.088,loss:3.735337734222412,entropy:3.1220476627349854,explained_var_old:0.391,explained_var_new:0.433
# batch i:670, episode_len:31
# kl:0.01485,lr_multiplier:0.088,loss:3.715684413909912,entropy:3.0892844200134277,explained_var_old:0.321,explained_var_new:0.381
# batch i:671, episode_len:40
# kl:0.02079,lr_multiplier:0.088,loss:3.7282207012176514,entropy:3.076416015625,explained_var_old:0.336,explained_var_new:0.405
# batch i:672, episode_len:24
# kl:0.01148,lr_multiplier:0.088,loss:3.737185478210449,entropy:3.076636791229248,explained_var_old:0.324,explained_var_new:0.378
# batch i:673, episode_len:27
# kl:0.01119,lr_multiplier:0.088,loss:3.8205676078796387,entropy:3.096099376678467,explained_var_old:0.276,explained_var_new:0.325
# batch i:674, episode_len:22
# kl:0.01014,lr_multiplier:0.088,loss:3.8613858222961426,entropy:3.1550183296203613,explained_var_old:0.284,explained_var_new:0.326
# batch i:675, episode_len:31
# kl:0.00878,lr_multiplier:0.132,loss:3.881115198135376,entropy:3.1146745681762695,explained_var_old:0.256,explained_var_new:0.304
# batch i:676, episode_len:58
# kl:0.02559,lr_multiplier:0.132,loss:3.96993350982666,entropy:3.1994545459747314,explained_var_old:0.168,explained_var_new:0.247
# batch i:677, episode_len:36
# kl:0.02849,lr_multiplier:0.132,loss:3.863818645477295,entropy:3.0430104732513428,explained_var_old:0.188,explained_var_new:0.262
# batch i:678, episode_len:21
# kl:0.04398,lr_multiplier:0.088,loss:3.916468620300293,entropy:3.20812726020813,explained_var_old:0.195,explained_var_new:0.295
# batch i:679, episode_len:12
# kl:0.02097,lr_multiplier:0.088,loss:3.9109692573547363,entropy:3.1154747009277344,explained_var_old:0.213,explained_var_new:0.274
# batch i:680, episode_len:11
# kl:0.03005,lr_multiplier:0.088,loss:3.8493239879608154,entropy:3.187422037124634,explained_var_old:0.271,explained_var_new:0.317
# batch i:681, episode_len:11
# kl:0.02079,lr_multiplier:0.088,loss:3.745438814163208,entropy:3.0564820766448975,explained_var_old:0.312,explained_var_new:0.354
# batch i:682, episode_len:31
# kl:0.01989,lr_multiplier:0.088,loss:3.93438458442688,entropy:3.129962921142578,explained_var_old:0.189,explained_var_new:0.294
# batch i:683, episode_len:31
# kl:0.03116,lr_multiplier:0.088,loss:3.858407974243164,entropy:3.1640520095825195,explained_var_old:0.247,explained_var_new:0.300
# batch i:684, episode_len:9
# kl:0.01266,lr_multiplier:0.088,loss:3.863063335418701,entropy:3.1824045181274414,explained_var_old:0.269,explained_var_new:0.327
# batch i:685, episode_len:15
# kl:0.01557,lr_multiplier:0.088,loss:3.823883533477783,entropy:3.1246256828308105,explained_var_old:0.296,explained_var_new:0.334
# batch i:686, episode_len:39
# kl:0.01532,lr_multiplier:0.088,loss:3.8440003395080566,entropy:3.15838623046875,explained_var_old:0.305,explained_var_new:0.376
# batch i:687, episode_len:30
# kl:0.02559,lr_multiplier:0.088,loss:3.800567865371704,entropy:3.12776517868042,explained_var_old:0.314,explained_var_new:0.355
# batch i:688, episode_len:31
# kl:0.02209,lr_multiplier:0.088,loss:3.8927483558654785,entropy:3.179374933242798,explained_var_old:0.272,explained_var_new:0.340
# batch i:689, episode_len:15
# kl:0.01163,lr_multiplier:0.088,loss:3.740703821182251,entropy:3.1563720703125,explained_var_old:0.346,explained_var_new:0.402
# batch i:690, episode_len:46
# kl:0.03082,lr_multiplier:0.088,loss:3.898970127105713,entropy:3.09635853767395,explained_var_old:0.259,explained_var_new:0.345
# batch i:691, episode_len:14
# kl:0.02955,lr_multiplier:0.088,loss:3.9387385845184326,entropy:3.1635708808898926,explained_var_old:0.216,explained_var_new:0.282
# batch i:692, episode_len:38
# kl:0.03227,lr_multiplier:0.088,loss:3.8128597736358643,entropy:3.2076737880706787,explained_var_old:0.320,explained_var_new:0.376
# batch i:693, episode_len:24
# kl:0.02554,lr_multiplier:0.088,loss:3.9774372577667236,entropy:3.2037224769592285,explained_var_old:0.245,explained_var_new:0.292
# batch i:694, episode_len:19
# kl:0.02084,lr_multiplier:0.088,loss:3.835439682006836,entropy:3.177076816558838,explained_var_old:0.300,explained_var_new:0.363
# batch i:695, episode_len:51
# kl:0.01304,lr_multiplier:0.088,loss:3.9817049503326416,entropy:3.199667453765869,explained_var_old:0.192,explained_var_new:0.266
# batch i:696, episode_len:12
# kl:0.01649,lr_multiplier:0.088,loss:3.8502326011657715,entropy:3.1415863037109375,explained_var_old:0.252,explained_var_new:0.301
# batch i:697, episode_len:17
# kl:0.01761,lr_multiplier:0.088,loss:3.8823418617248535,entropy:3.1533355712890625,explained_var_old:0.246,explained_var_new:0.299
#
# quit
